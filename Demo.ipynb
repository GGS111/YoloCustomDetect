# %% [markdown]
# # Load Libs

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# # Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\misha/.cache\torch\hub\master.zip
# YOLOv5  2022-4-5 torch 1.8.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %% [markdown]
# # Load Image
# # URL

# %%
img = 'https://s0.rbk.ru/v6_top_pics/media/img/7/30/756355321353307.jpg'

# %% [markdown]
# # Local File

# %%
img = os.path.join('test', '', '10.jpg')

# %% [markdown]
# # Demo

# %%
# %matplotlib inline 
results = model(img)
plt.imshow(np.squeeze(results.render()))
plt.show()
