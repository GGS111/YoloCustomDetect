# %% [markdown]
# # Load Libs

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# # Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\misha/.cache\torch\hub\master.zip
# YOLOv5  2022-4-5 torch 1.8.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %% [markdown]
# # Demo
# # URL

# %%
img = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqRC8WosGv2itDwCuunQEfyMpPj8vkfZVn4w&usqp=CAU'

# %% [markdown]
# # Local File

# %%
img = os.path.join('dataset/train', 'images', '17_jpg.rf.9492d909619132fb4f0e5f6e4f7a7302.jpg')

# %%
# %matplotlib inline 
results = model(img)
plt.imshow(np.squeeze(results.render()))
plt.show()
