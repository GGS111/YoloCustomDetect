# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\misha/.cache\torch\hub\master.zip
# YOLOv5  2022-4-5 torch 1.8.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
img = 'https://img.championat.com/s/735x490/news/big/x/k/glava-associacii-futbola-shvecii-stykovoj-match-v-rossii-cherez-mesyac-eto-pochti-nemyslim_1645699708415945349.jpg'
results = model(img)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()
